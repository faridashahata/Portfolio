# %%
import tensorflow

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers.legacy import SGD

# %%
import random
import json
import pickle
import numpy as np
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('omw-1.4')
nltk.download('wordnet')
nltk.download('punkt')
import tensorflow as tf
from tensorflow.keras import datasets, layers, models


lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# This simple Chatbot is built on a very simlpe intents file to grasp a typical structure of building a Chatbot.
# The steps followed can be found in the following article:
#
# https://www.projectpro.io/article/python-chatbot-project-learn-to-build-a-chatbot-from-scratch/429#toc-10

# %% [markdown]
# ### **STEP 1: Create a JSON file of intents:**
#
#
#
# *   The patterns correspond to sentences expected from the users, on which the model will be trained
# *   Responses correspond to the exact responses the chatbot will generate once it recognizes the corresponding tag (chosen at random from the list of provided responses)
#
#
# *   Tags are single words which help us classify the patterns; they are the output of a learned model which associates patterns with tags.

# %%
# Create a json file of intents: 
intents
# Out:
# {'intents': [{'tag': 'greetings',
#    'patterns': ['hello',
#     'hi',
#     'hey',
#     'good morning',
#     'good day',
#     'greetings',
#     "what's up?",
#     'How is it going?'],
#    'responses': ['Hello', 'Hey!', 'What can I do for you?']},
#   {'tag': 'goodbye',
#    'patterns': ['bye', 'I am leaving', 'see ya', 'goodbye', 'see you later'],
#    'responses': ['Goodbye!', 'Talk to you later!']},
#   {'tag': 'name',
#    'patterns': ["What's your name?",
#     'What should I call you?',
#     'Do you have a name?',
#     'who are you?',
#     'tell me about yourself'],
#    'responses': ['You can call me Kiwi!', "I'm Kiwi, Farida's assitant :)"]},
#   {'tag': 'order',
#    'patterns': ["I'd like to order something",
#     'I want to buy something',
#     'I want to place an order',
#     'What do you recommend?'],
#    'responses': ['Let me direct you to our page of currently available restaurants you can order from, at this moment!',
#     'There are a ton of options! Let me direct you to them!']},
#   {'tag': 'complaint',
#    'patterns': ['I want to place a complaint',
#     'I want to return my order',
#     'my order does not match the description',
#     'The driver is late',
#     ' I have not received my order yet!',
#     'I am not happy with my order'],
#    'responses': ['Oh! I am sad to hear that! Let me direct you to someone who can help!',
#     'Oh no! Allow me to fix that right away!']}]}

# %% [markdown]
# ### **STEP 2: Prepare the training data:**

# %%
###########################################################################################################################
####                                                                                                                   ####
#### STEP 2.1: Tokenize and Lemmatize the needed vocabularies and prepare the inputs and targets of the training data: #### 
####                                                                                                                   ####
###########################################################################################################################

words = []                                    # vocabulary for the patterns (lemmatized single words into their roots)
classes = []                                  # vocabulary for the tags 

data_X = []                                   # To store the patterns as they are
data_y = []                                   # To store the tags corresponding to the patterns in data_X
ignore_letters = ["?", "!", ",", "."]         # Characters to skip over when lemmatizing 

for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        # word_tokenize will split up the sentence into words:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        data_X.append(pattern)
        data_y.append(intent["tag"])

    if intent['tag'] not in classes:
        classes.append(intent['tag'])


# The lemmatizer will bring each word from the vocabulary to its root, skipping over punctuation:
words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))


##################################################################################################
####                                                                                          ####
#### STEP 2.2: Create the Bag-of-Words Model: from words to zeros and ones to feed the model: #### 
####                                                                                          ####
##################################################################################################

training = []
output_empty = [0]*len(classes)

for idx, doc in enumerate(data_X):
    bag = []                                    # A bag-of-words list created for each pattern of the same size as words (the patterns vocabulary)
    text = lemmatizer.lemmatize(doc.lower())    # Lemmatize the pattern sentence before matching words with vocabulary

    for word in words:
        bag.append(1) if word in text else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(data_y[idx])] = 1  # A bag-of-words list which contains 1 only for the corresponding tag of the pattern
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training, dtype=object)

train_x = list(training[:, 0])                  # contains the bag-of-words list for the patterns.
train_y = list(training[:, 1])                  # contains the bag-of-words list for the corresponding tags/classes.

# %% [markdown]
# ### **STEP 3: Build and train the model using keras:**

# %%
##  Build a simple model with relu activations and a final layer using softmax 
### Make sure the number of outputs of the final layer matches the number of classes there are

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Optimizer to use: we can also use Adam or other:
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 4ms/step - loss: 1.6143 - accuracy: 0.2857
# Epoch 2/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.5677 - accuracy: 0.2500
# Epoch 3/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.5623 - accuracy: 0.3214
# Epoch 4/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4339 - accuracy: 0.3929
# Epoch 5/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4034 - accuracy: 0.5714
# Epoch 6/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.3235 - accuracy: 0.6429
# Epoch 7/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2213 - accuracy: 0.6429
# Epoch 8/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.1335 - accuracy: 0.6071
# Epoch 9/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0943 - accuracy: 0.6429
# Epoch 10/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.1201 - accuracy: 0.6786
# Epoch 11/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.1368 - accuracy: 0.6786
# Epoch 12/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9357 - accuracy: 0.6786
# Epoch 13/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8512 - accuracy: 0.8214
# Epoch 14/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6947 - accuracy: 0.8214
# Epoch 15/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7005 - accuracy: 0.8929
# Epoch 16/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6307 - accuracy: 0.9286
# Epoch 17/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.8929
# Epoch 18/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5655 - accuracy: 0.8571
# Epoch 19/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6295 - accuracy: 0.8571
# Epoch 20/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6127 - accuracy: 0.8571
# Epoch 21/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4542 - accuracy: 0.8214
# Epoch 22/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3581 - accuracy: 0.9286
# Epoch 23/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3215 - accuracy: 0.9643
# Epoch 24/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3453 - accuracy: 0.9286
# Epoch 25/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2851 - accuracy: 0.9286
# Epoch 26/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3383 - accuracy: 0.8929
# Epoch 27/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4041 - accuracy: 0.8571
# Epoch 28/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3037 - accuracy: 0.9643
# Epoch 29/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5503 - accuracy: 0.8571
# Epoch 30/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2492 - accuracy: 0.9286
# Epoch 31/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3184 - accuracy: 0.8929
# Epoch 32/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2376 - accuracy: 0.9286
# Epoch 33/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1734 - accuracy: 0.9286
# Epoch 34/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2609 - accuracy: 0.8929
# Epoch 35/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2893 - accuracy: 0.9286
# Epoch 36/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0985 - accuracy: 1.0000
# Epoch 37/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 1.0000
# Epoch 38/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2654 - accuracy: 0.9286
# Epoch 39/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 1.0000
# Epoch 40/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2696 - accuracy: 0.9286
# Epoch 41/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1463 - accuracy: 0.9643
# Epoch 42/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9643
# Epoch 43/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1654 - accuracy: 0.9643
# Epoch 44/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1019 - accuracy: 1.0000
# Epoch 45/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 46/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9643
# Epoch 47/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2194 - accuracy: 0.9286
# Epoch 48/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 1.0000
# Epoch 49/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2855 - accuracy: 0.9286
# Epoch 50/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1652 - accuracy: 0.9643
# Epoch 51/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1759 - accuracy: 0.8929
# Epoch 52/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9643
# Epoch 53/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9643
# Epoch 54/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1348 - accuracy: 0.9643
# Epoch 55/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0673 - accuracy: 1.0000
# Epoch 56/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9643
# Epoch 57/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 58/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1278 - accuracy: 0.9643
# Epoch 59/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 60/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 0.9643
# Epoch 61/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1334 - accuracy: 0.9643
# Epoch 62/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 63/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 64/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 65/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 66/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 67/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9643
# Epoch 68/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 1.0000
# Epoch 69/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 70/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 71/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 72/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 73/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 74/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 75/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 76/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 77/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1427 - accuracy: 0.9286
# Epoch 78/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 79/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 80/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 81/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0853 - accuracy: 0.9643
# Epoch 82/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1130 - accuracy: 0.9643
# Epoch 83/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 84/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 1.0000
# Epoch 85/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 1.0000
# Epoch 86/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0869 - accuracy: 1.0000
# Epoch 87/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 88/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 89/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9643
# Epoch 90/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 91/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 92/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 93/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0722 - accuracy: 1.0000
# Epoch 94/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 95/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0716 - accuracy: 1.0000
# Epoch 96/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 97/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 98/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 99/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 100/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 1.0000
# Epoch 101/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 102/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 1.0000
# Epoch 103/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 104/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 105/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 106/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.9643
# Epoch 107/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 108/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0553 - accuracy: 0.9643
# Epoch 109/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9643
# Epoch 110/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 111/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.9643
# Epoch 112/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0623 - accuracy: 1.0000
# Epoch 113/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0541 - accuracy: 0.9643
# Epoch 114/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1240 - accuracy: 0.9643
# Epoch 115/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 116/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1075 - accuracy: 0.9643
# Epoch 117/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 118/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 119/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 120/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 121/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 122/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 123/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 124/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 125/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 126/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 127/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 128/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 129/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 130/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 131/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 132/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 133/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 134/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 135/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 136/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 137/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 138/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 139/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 140/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 141/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 142/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 0.9643
# Epoch 143/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 144/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 145/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 146/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 147/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 148/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 149/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 150/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 151/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 152/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 153/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9643
# Epoch 154/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 155/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0928 - accuracy: 0.9643
# Epoch 156/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 157/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1662 - accuracy: 0.9643
# Epoch 158/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9643
# Epoch 159/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9643
# Epoch 160/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 161/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 162/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 163/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 164/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0616 - accuracy: 0.9643
# Epoch 165/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 166/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 167/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 168/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 169/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 170/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0867 - accuracy: 0.9643
# Epoch 171/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 172/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 173/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 174/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0801 - accuracy: 0.9643
# Epoch 175/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 176/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 177/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 178/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9643
# Epoch 179/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 180/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 181/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9643
# Epoch 182/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 183/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 184/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 185/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 186/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 187/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 188/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 189/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 0.9643
# Epoch 190/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 191/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 192/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 193/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 194/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 195/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 196/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 197/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 198/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 199/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 200/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 1.0000

# %% [markdown]
# ### **STEP 4: Process user input and generate response:**

# %%
# Preprocessing the input: 

def clean_text(text): 
  """ Tokenizes and lemmatizes the incoming user query
      
        Parameters: 
          text(str): The user query
        Returns: 
          tokens(list): a list of separate words' roots from the query
  """          
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens


def bag_of_words(text, vocab): 
  """ Turns the cleaned text into an array of 0 and 1, using the bag-of-words model
      
        Parameters: 
          text(str): The user query, cleaned
          vocab(list): list of vocabulary words
        Returns: 
          (array): a numpy array of 0 and 1, of the same size as vocab
  """     
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)


def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  # Generate probabilities for predictions:
  result = model.predict(np.array([bow]))[0] 
  # Filter out predictions for classes below a certain threshold:  
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  # Sort out predicted classes from highest to lowest probability:
  y_pred.sort(key=lambda x: x[1], reverse=True)
  # Return a list of predicted tags from most to least likely:
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json):
  """ Generates a response randomly, based on the tag given by pred_class function, from the corresponding responses 
      in the json file of intents
    
        Returns: 
          (string): a response to output to the user
  """  
  if len(intents_list)==0:
    result = "Sorry! I don't understand"

  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i['responses'])
        break
  return result

# %%
# Interacting with the chatbot:
intents_json = json.loads(open('intents.json').read())
print("Press 0 if you don't want to chat with our Chatbot")
while True:

  message = input("")
  if message == "0":
    break
  intents_list = pred_class(message, words, classes)
  result = get_response(intents_list, intents_json)
  print(result)
# Out:
# Press 0 if you don't want to chat with our Chatbot
# Hi
# 1/1 [==============================] - 0s 92ms/step
# Hey!
# How are you?
# 1/1 [==============================] - 0s 25ms/step
# I'm Kiwi, Farida's assitant :)
# Nice to meet you, Kiwi
# 1/1 [==============================] - 0s 22ms/step
# You can call me Kiwi!
# I wanted to buy something...
# 1/1 [==============================] - 0s 49ms/step
# There are a ton of options! Let me direct you to them!
# I actually bought something earlier and wanted to return it
# 1/1 [==============================] - 0s 22ms/step
# Sorry! I don't understand
# I want to complain about an item
# 1/1 [==============================] - 0s 25ms/step
# Sorry! I don't understand
# I do not like the item I bought
# 1/1 [==============================] - 0s 35ms/step
# Oh no! Allow me to fix that right away!
# Ok, have a good day, bye
# 1/1 [==============================] - 0s 22ms/step
# Talk to you later!
# 0
